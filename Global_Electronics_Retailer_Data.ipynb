# %%
import pandas as pd

customer_df = pd.read_csv('/content/drive/MyDrive/Global+Electronics+Retailer/Customers.csv', encoding = 'iso-8859-1')
customer_df.head()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ###**Cleaning Sales Table**

# %%
sale_df = pd.read_csv('/content/Sales.csv')
sale_df.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
print(sale_df.isnull().sum())
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
print(sale_df.duplicated().sum())
# Out:
# 0

# %%
sale_df['Order Date'] = pd.to_datetime(sale_df['Order Date'], errors='coerce').dt.strftime('%Y-%m-%d')
sale_df['Delivery Date'] = pd.to_datetime(sale_df['Delivery Date'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
sale_df['Order Date'] = pd.to_datetime(sale_df['Order Date'], errors='coerce', format='%Y-%m-%d')
sale_df['Delivery Date'] = pd.to_datetime(sale_df['Delivery Date'], errors='coerce', format='%Y-%m-%d')

# %%
sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   Delivery Date  13165 non-null  datetime64[ns]
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](2), int64(6), object(1)
# memory usage: 4.3+ MB

# %%
sale_df.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051         0
# 2        366001          2 2016-01-01    2016-01-13      1269051         0
# 3        366002          1 2016-01-01    2016-01-12       266019         0
# 4        366002          2 2016-01-01    2016-01-12       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
# Replace StoreKey value of 0 with 67 in the Sales DataFrame
sale_df['StoreKey'] = sale_df['StoreKey'].replace(0, 67)

# %%
sale_df.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1 2016-01-01           NaT       265598        10
# 1        366001          1 2016-01-01    2016-01-13      1269051        67
# 2        366001          2 2016-01-01    2016-01-13      1269051        67
# 3        366002          1 2016-01-01    2016-01-12       266019        67
# 4        366002          2 2016-01-01    2016-01-12       266019        67
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
sale_df.to_csv('sales_cleaned.csv', index=False)

# %% [markdown]
# ###**Cleaning Exchange Rates**

# %%
import pandas as pd
ex_df = pd.read_csv('/content/Exchange_Rates.csv')
ex_df.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
ex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
print(ex_df.isnull().sum())
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
print(ex_df.duplicated().sum())
# Out:
# 0

# %%
ex_df['Date'] = pd.to_datetime(ex_df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
ex_df.head()
# Out:
#          Date Currency  Exchange
# 0  2015-01-01      USD    1.0000
# 1  2015-01-01      CAD    1.1583
# 2  2015-01-01      AUD    1.2214
# 3  2015-01-01      EUR    0.8237
# 4  2015-01-01      GBP    0.6415

# %%
ex_df['Date'] = pd.to_datetime(ex_df['Date'], errors='coerce', format='%Y-%m-%d')

# %%
ex_df.head()
# Out:
#         Date Currency  Exchange
# 0 2015-01-01      USD    1.0000
# 1 2015-01-01      CAD    1.1583
# 2 2015-01-01      AUD    1.2214
# 3 2015-01-01      EUR    0.8237
# 4 2015-01-01      GBP    0.6415

# %%
ex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
ex_df['Exchange'] = ex_df['Exchange'].round(2)

# %%
ex_df.head()
# Out:
#         Date Currency  Exchange
# 0 2015-01-01      USD      1.00
# 1 2015-01-01      CAD      1.16
# 2 2015-01-01      AUD      1.22
# 3 2015-01-01      EUR      0.82
# 4 2015-01-01      GBP      0.64

# %%
ex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
duplicate_rows = ex_df.duplicated(subset=['Date', 'Currency'])
print("Duplicates found:", duplicate_rows.sum())
# Out:
# Duplicates found: 0

# %%
# Check for duplicates based on Currency and Date
duplicate_rows = ex_df[ex_df.duplicated(subset=['Currency', 'Date'], keep=False)]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Date, Currency, Exchange]
# Index: []

# %%
ex_df.to_csv('ExchangeRate_cleaned.csv', index=False)

# %% [markdown]
# ###**Cleaning Store Table**

# %%
store_df = pd.read_csv('/content/Electronic_Data/Stores.csv')
store_df.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %%
store_df['Open Date'] = pd.to_datetime(store_df['Open Date'], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
store_df.head()
# Out:
#    StoreKey    Country                         State  Square Meters  \
# 0         1  Australia  Australian Capital Territory          595.0
# 1         2  Australia            Northern Territory          665.0
# 2         3  Australia               South Australia         2000.0
# 3         4  Australia                      Tasmania         2000.0
# 4         5  Australia                      Victoria         2000.0
#
#     Open Date
# 0  2008-01-01
# 1  2008-01-12
# 2  2012-01-07
# 3  2010-01-01
# 4  2015-12-09

# %%
store_df['Open Date'] = pd.to_datetime(store_df['Open Date'], errors='coerce', format='%Y-%m-%d')

# %%
store_df.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0 2008-01-01
# 1         2  Australia            Northern Territory          665.0 2008-01-12
# 2         3  Australia               South Australia         2000.0 2012-01-07
# 3         4  Australia                      Tasmania         2000.0 2010-01-01
# 4         5  Australia                      Victoria         2000.0 2015-12-09

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 2.7+ KB

# %%
store_df['Square Meters'].fillna(0, inplace=True)
store_df.tail()
# Out:
# <ipython-input-45-c40bd485b5ca>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   store_df['Square Meters'].fillna(0, inplace=True)
#     StoreKey        Country          State  Square Meters  Open Date
# 62        63  United States           Utah         2000.0 2008-03-06
# 63        64  United States  Washington DC         1330.0 2010-01-01
# 64        65  United States  West Virginia         1785.0 2012-01-01
# 65        66  United States        Wyoming          840.0 2014-01-01
# 66         0         Online         Online            0.0 2010-01-01

# %%
store_df['Square Meters'] = store_df['Square Meters'].astype(int)

# %%
print(store_df['Square Meters'].dtypes)
print(store_df.head())
# Out:
# int64
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory            595 2008-01-01
# 1         2  Australia            Northern Territory            665 2008-01-12
# 2         3  Australia               South Australia           2000 2012-01-07
# 3         4  Australia                      Tasmania           2000 2010-01-01
# 4         5  Australia                      Victoria           2000 2015-12-09

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     int64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 2.7+ KB

# %%
import numpy as np
store_df['StoreKey'] = store_df['StoreKey'].replace(0, np.nan)  # Temporarily replace 0 with NaN
store_df['StoreKey'] = store_df['StoreKey'].fillna(store_df['StoreKey'].max() + 1).astype(int)

# %%
store_df.tail()
# Out:
#     StoreKey        Country          State  Square Meters  Open Date
# 62        63  United States           Utah           2000 2008-03-06
# 63        64  United States  Washington DC           1330 2010-01-01
# 64        65  United States  West Virginia           1785 2012-01-01
# 65        66  United States        Wyoming            840 2014-01-01
# 66        67         Online         Online              0 2010-01-01

# %%
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  67 non-null     int64
#  4   Open Date      67 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 2.7+ KB

# %%
store_df.to_csv('store_cleaned.csv', index=False)

# %% [markdown]
# ###**Cleaning Product Table**

# %%
product_df = pd.read_csv('/content/Products.csv')
product_df.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
print(product_df.isnull().sum())
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
print(product_df.duplicated().sum())
# Out:
# 0

# %%
product_df['Unit Cost USD'] = product_df['Unit Cost USD'].replace('[\$,]', '', regex=True).astype(float)
product_df['Unit Price USD'] = product_df['Unit Price USD'].replace('[\$,]', '', regex=True).astype(float)

# %%
product_df.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#    Unit Cost USD  Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0           6.62           12.99             101     MP4&MP3            1
# 1           6.62           12.99             101     MP4&MP3            1
# 2           7.40           14.52             101     MP4&MP3            1
# 3          11.00           21.57             101     MP4&MP3            1
# 4          11.00           21.57             101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   float64
#  5   Unit Price USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
product_df.to_csv('product_cleaned.csv', index=False)

# %% [markdown]
# ### **Cleaning Customer Table**

# %%
print(customer_df.Country.unique()) #UniqueValues for countries
# Out:
# ['Australia' 'Canada' 'Germany' 'France' 'Italy' 'Netherlands'
#  'United kingdom' 'United states']

# %%
print(customer_df.State.unique())
# Out:
# ['South Australia' 'Western Australia' 'Victoria' 'Queensland'
#  'Northern Territory' 'New South Wales' 'Tasmania'
#  'Australian Capital Territory' 'British Columbia' 'Quebec' 'Ontario'
#  'Alberta' 'Nova Scotia' 'Saskatchewan' 'Nunavut' 'Prince Edward Island'
#  'Manitoba' 'Newfoundland and Labrador' 'Yukon' 'Northwest Territories'
#  'New Brunswick' 'Brandenburg' 'Rheinland-Pfalz' 'Freistaat Bayern'
#  'Baden-Württemberg' 'Nordrhein-Westfalen' 'Niedersachsen'
#  'Sachsen-Anhalt' 'Mecklenburg-Vorpommern' 'Freistaat Sachsen'
#  'Freistaat Thüringen' 'Berlin' 'Hessen' 'Saarland' 'Schleswig-Holstein'
#  'Freie Hansestadt Bremen' 'Hamburg' 'Rhône-Alpes' 'Île-de-France'
#  'Guyane' 'Alsace' 'Aquitaine' 'Champagne-Ardenne' 'Nord-Pas-de-Calais'
#  'Guadeloupe' 'Franche-Comté' "Provence-Alpes-Côte d'Azur"
#  'Poitou-Charentes' 'Limousin' 'Midi-Pyrénées' 'Picardie'
#  'Haute-Normandie' 'Auvergne' 'Pays de la Loire' 'Lorraine'
#  'Basse-Normandie' 'Centre' 'Languedoc-Roussillon' 'Martinique'
#  'Bourgogne' 'Bretagne' 'Corse' 'Mayotte' 'Reggio Calabria' 'Benevento'
#  'Vicenza' 'Ferrara' 'Roma' 'Agrigento' 'Imperia' 'Milano' 'Parma'
#  'Bergamo' 'Ragusa' 'Pordenone' 'Savona' 'Lucca' 'Cuneo' "L'Aquila"
#  'Trento' 'Lecce' 'Padova' 'Bologna' 'Salerno' 'Biella' 'Chieti' 'Genova'
#  'Torino' 'Vibo Valentia' 'Catanzaro' 'Ancona' 'Perugia' 'Latina'
#  'Belluno' 'Treviso' 'Pavia' 'Mantova' 'Varese' 'Pistoia' 'Nuoro' 'Siena'
#  'Piacenza' 'Massa' 'Catania' 'Brescia' 'Sassari' 'Rovigo' 'Cremona'
#  'Firenze' 'Grosseto' 'Caserta' 'Isernia' 'Sondrio' 'Venezia' 'Oristano'
#  'Messina' 'Livorno' 'Palermo' 'Pisa' 'Verona' 'Como' 'Cosenza' 'Bolzano'
#  'Novara' 'Avellino' 'Taranto' 'Vercelli' 'Gorizia' 'Modena' 'Frosinone'
#  'Foggia' 'Alessandria' 'Teramo' 'Bari' 'Udine' 'Ascoli Piceno' 'Trapani'
#  'Reggio Emilia' 'Cagliari' 'Prato' 'Napoli' 'Asti' 'Siracusa' 'Rieti'
#  'Trieste' 'Crotone' 'Matera' 'Potenza' 'Macerata' 'Viterbo' 'Arezzo'
#  'Aosta' 'Campobasso' 'Brindisi' 'Lecco' 'Ravenna' 'La Spezia' 'Pescara'
#  'Rimini' 'Forli' 'Termi' 'Limburg' 'Utrecht' 'Noord-Holland'
#  'Noord-Brabant' 'Gelderland' 'Friesland' 'Groningen' 'Drenthe'
#  'Zuid-Holland' 'Flevoland' 'Overijssel' 'Zeeland' 'Falkirk' 'Ceredigion'
#  'North East Lincolnshire' 'Aberdeenshire' 'York' 'Pembrokeshire'
#  'Leicester' 'Highland' 'Tendring' 'Horsham' 'Newport' 'Bristol'
#  'Newark and Sherwood' 'Argyllshire' 'Lincoln' 'Tamworth' 'Fylde' 'Lewes'
#  'Rhondda Cynon Taf' 'Bromsgrove' 'Ripon' 'Cornwall' 'South Lanarkshire'
#  'Shropshire' 'Perth and Kinross' 'Crawley' 'Staffordshire' 'Mendip'
#  'Forest Heath' 'Moray' 'Bracknell Forest' 'Anglesey' 'Bolsover'
#  'Calderdale' 'Ashford' 'Sussex' 'Darlington' 'East Devon' 'Monmouthshire'
#  'Gloucester' 'Mid Devon' 'Somerset' 'Hereford'
#  'Bath and North East Somerset' 'Bassetlaw' 'Christchurch'
#  'West Berkshire' 'Gwynedd' 'Suffolk' 'Tewkesbury' 'Colchester'
#  'Llandrindod Wells' 'Harrogate' 'Winchester' 'Angus' 'Derbyshire Dales'
#  'Dacorum' 'Suffolk Coastal' 'Wiltshire' 'Leeds' 'Kennet' 'Hampshire'
#  'Norfolk' 'Northumberland' 'Doncaster' 'Purbeck' 'Wyre Forest'
#  'Redcar & Cleveland' 'West Dorset' 'Ipswich' 'Powys' 'Midlothian' 'Fife'
#  'North Ayrshire' 'Carmarthenshire' 'Birmingham' 'South Oxfordshire'
#  'North Yorkshire' 'Cheshire West and Chester' 'Scottish Borders'
#  'Lichfield' 'Rushcliffe' 'Arun' 'Dumfriesshire' 'Wakefield'
#  'Denbighshire' 'Plymouth' 'St Edmundsbury' 'Edinburgh' 'Liverpool' 'Kent'
#  'Warwick' 'Gedling' 'Shetland' 'Flintshire' 'Gravesham'
#  'Central Bedfordshire' 'North Dorset' 'Lancaster' 'Breckland'
#  'East Riding of Yorkshire' 'Exeter' 'Vale of White Horse' 'Cherwell'
#  'South Holland' 'South Lakeland' 'Stroud' 'Orkney Islands' 'West Lindsey'
#  'Stratford-on-Avon' 'West Oxfordshire' 'Bedford' 'Rother' 'Isle of Man'
#  'Swindon' 'Charnwood' 'Waverley' 'Wolverhampton' 'Aylesbury Vale'
#  'Merton' 'Sevenoaks' 'Allerdale' 'Bolton' 'Selby' 'Berkshire' 'Copeland'
#  'Chelmsford' 'South Kesteven' 'Cheshire East' 'Boston' 'County Durham'
#  'Mid Suffolk' 'Wandsworth' 'West Dunbartonshire' 'Erewash' 'Babergh'
#  'South Hams' 'Wigan' 'South Ayrshire' 'Rotherham' 'Isle of Wight'
#  'Cotswold' 'Worcester' 'Rutland' 'East Northamptonshire' 'Rugby'
#  'Stirling' 'North Kesteven' 'Comhairle nan Eilean Siar' 'Walsall'
#  'Knowsley' 'South Somerset' 'North Lincolnshire' 'South Norfolk'
#  'Aberdeen' 'Welwyn Hatfield' 'Kirkcudbrightshire' 'Carlisle' 'Hillingdon'
#  'West Norfolk' 'Kirklees' 'New Forest' 'Swansea' 'Craven' 'Camden'
#  'North Somerset' 'Teignbridge' 'Melton' 'Conwy' 'Enfield' 'Glasgow'
#  'Braintree' 'Chichester' 'North Hertfordshire' 'East Lothian'
#  'Renfrewshire' 'Eden' 'Uttlesford' 'Mid Sussex' 'Peterborough' 'Ashfield'
#  'Redbridge' 'Sheffield' 'Newcastle' 'Harlow' 'East Hampshire'
#  'Caerphilly' 'North Warwickshire' 'Brentwood' 'Tameside'
#  'Brighton and Hove' 'Rossendale' 'Swale' 'Sutton' 'Huntingdonshire'
#  'St Albans' 'Dudley' 'East Hertfordshire' 'Guildford' 'Cambridge'
#  'Woking' 'Daventry' 'Vale of Glamorgan' 'East Ayrshire' 'Bradford'
#  'South Buckinghamshire' 'Merthyr Tydfil' 'West Lothian' 'East Lindsey'
#  'Hambleton' 'Tower Hamlets' 'Test Valley' 'Dartford' 'Sunderland'
#  'Medway' 'Rochdale' 'Bury' 'Oxford' 'Bridgend' 'South Derbyshire'
#  'Milton Keynes' 'Southampton' 'Wokingham' 'Nottingham' 'Stevenage'
#  'Wirral' 'Dundee' 'Amber Valley' 'Harrow' 'East Dorset' 'Maidstone'
#  'Wigtownshire' 'Gateshead' 'Telford and Wrekin' 'Wellingborough'
#  'Runnymede' 'Wrexham' 'Cannock Chase' 'Kensington and Chelsea'
#  'South Gloucestershire' 'Wycombe' 'South Staffordshire' 'Sandwell'
#  'Bromley' 'Torridge' 'Burnley' 'Sefton' 'Ribble Valley' 'Chiltern'
#  'Hastings' 'East Staffordshire' 'Barnet' 'Reigate and Banstead'
#  'Basildon' 'Tandridge' 'Westminster' 'Warrington' 'West Lancashire'
#  'Preston' 'Canterbury' 'Wealden' 'Havering' 'West Devon' 'Islington'
#  'Wyre' 'Kinross-Shire' 'Waveney' 'North Lanarkshire' 'Ely'
#  'Neath Port Talbot' 'Nuneaton & Bedworth' 'Chesterfield' 'Mole Valley'
#  'South Northamptonshire' 'Broxbourne' 'Cardiff' 'Hackney' 'Redditch'
#  'Tunbridge Wells' 'Haringey' 'Malvern Hills' 'Broxtowe' 'Spelthorne'
#  'Coventry' 'Newmarket' 'Lanarkshire' 'East Dunbartonshire'
#  'Stockton-on-Tees' 'California' 'North Carolina' 'Maryland' 'Hawaii'
#  'Colorado' 'Florida' 'Michigan' 'Alabama' 'Missouri' 'Illinois'
#  'New York' 'Texas' 'Mississippi' 'Georgia' 'Utah' 'Delaware' 'Wisconsin'
#  'New Hampshire' 'Kansas' 'Vermont' 'Nevada' 'Pennsylvania'
#  'Massachusetts' 'Washington' 'New Jersey' 'Virginia' 'Ohio' 'Iowa'
#  'Kentucky' 'Washington DC' 'Arkansas' 'Oklahoma' 'Oregon' 'Maine' 'Idaho'
#  'Minnesota' 'Arizona' 'Indiana' 'Connecticut' 'West Virginia' 'Nebraska'
#  'Tennessee' 'Louisiana' 'Alaska' 'North Dakota' 'Montana'
#  'South Carolina' 'New Mexico' 'Rhode Island' 'South Dakota' 'Wyoming']

# %%
print(customer_df.Continent.unique())
# Out:
# ['Australia' 'North America' 'Europe']

# %%
print(customer_df.shape)
# Out:
# (15266, 10)

# %%
print(customer_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB
# None

# %%
print(customer_df.isnull().sum())
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customer_df.dropna(inplace=True)
print(customer_df.isnull().sum())
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
print(customer_df.duplicated().sum())
# Out:
# 0

# %%
customer_df['Birthday'] = pd.to_datetime(customer_df['Birthday'], errors='coerce', format='%Y-%m-%d')
customer_df['Gender'] = customer_df['Gender'].astype('category')
customer_df['City'] = customer_df['City'].str.title()
customer_df['Country'] = customer_df['Country'].str.title()
customer_df['State'] = customer_df['State'].str.title()
customer_df['Continent'] = customer_df['Continent'].str.title()
customer_df['Name'] = customer_df['Name'].str.title()
print(customer_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15256 entries, 0 to 15265
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15256 non-null  int64
#  1   Gender       15256 non-null  category
#  2   Name         15256 non-null  object
#  3   City         15256 non-null  object
#  4   State        15256 non-null  object
#  5   Zip Code     15256 non-null  object
#  6   Country      15256 non-null  object
#  7   Continent    15256 non-null  object
#  8   Birthday     15256 non-null  datetime64[ns]
# dtypes: category(1), datetime64[ns](1), int64(1), object(6)
# memory usage: 1.1+ MB
# None

# %%
customer_df.head()
# Out:
#    CustomerKey  Gender               Name            City              State  \
# 0          301  Female      Lilly Harding  Wandearah east    South Australia
# 1          325  Female       Madison Hull      Mount budd  Western Australia
# 2          554  Female      Claire Ferres       Winjallok           Victoria
# 3          786    Male  Jai Poltpalingada    Middle river    South Australia
# 4         1042    Male    Aidan Pankhurst   Tawonga south           Victoria
#
#   Zip Code    Country  Continent   Birthday
# 0     5523  Australia  Australia 1939-07-03
# 1     6522  Australia  Australia 1979-09-27
# 2     3380  Australia  Australia 1947-05-26
# 3     5223  Australia  Australia 1957-09-17
# 4     3698  Australia  Australia 1965-11-19

# %%
customer_df.drop(['State Code'], axis=1, inplace=True)
customer_df.head()
# Out:
#    CustomerKey  Gender               Name            City              State  \
# 0          301  Female      Lilly Harding  Wandearah East    South Australia
# 1          325  Female       Madison Hull      Mount Budd  Western Australia
# 2          554  Female      Claire Ferres       Winjallok           Victoria
# 3          786    Male  Jai Poltpalingada    Middle River    South Australia
# 4         1042    Male    Aidan Pankhurst   Tawonga South           Victoria
#
#   Zip Code    Country  Continent   Birthday
# 0     5523  Australia  Australia 1939-07-03
# 1     6522  Australia  Australia 1979-09-27
# 2     3380  Australia  Australia 1947-05-26
# 3     5223  Australia  Australia 1957-09-17
# 4     3698  Australia  Australia 1965-11-19

# %%
customer_df['City'] = customer_df['City'].str.replace(r'[^a-zA-Z\s]', '', regex=True)
customer_df
# Out:
#        CustomerKey  Gender               Name                 City  \
# 0              301  Female      Lilly Harding       Wandearah East
# 1              325  Female       Madison Hull           Mount Budd
# 2              554  Female      Claire Ferres            Winjallok
# 3              786    Male  Jai Poltpalingada         Middle River
# 4             1042    Male    Aidan Pankhurst        Tawonga South
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa DuKová              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State Zip Code        Country      Continent   Birthday
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
# [15256 rows x 9 columns]

# %%
earliest_birth = customer_df['Birthday'].min()
latest_birth = customer_df['Birthday'].max()
print(earliest_birth)
print(latest_birth)
# Out:
# 1935-02-03 00:00:00
# 2002-02-18 00:00:00

# %%
customer_df.to_csv('cleaned_customers.csv', index=False)
